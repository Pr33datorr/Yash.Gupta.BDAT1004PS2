# %% [markdown]
# # Data Programming Problem Set # 2
#
# ## Submitted by: Yash Gupta ( 200569784 )

# %% [markdown]
# # Problem Set 2- Introduction
#
# This problem set is based on lectures 4,5 and 6. For a complete list of topics please consult page 2 of the course syllabus. Please consult the “Instructions for Problem Set Submissions” document under course information before submitting your  assignment.

# %% [markdown]
# ## Question 1:
# ###    Consider the following Python module:
#     a = 0
#     def b():
#     global a
#     a = c(a)
#     def c(a):
#     return a + 2
#
# #### After importing the module into the interpreter, you execute:
#
#     >>> b()
#     >>> b()
#     >>> b()
#     >>> a
#     ?
# ### What value is displayed when the last expression (a) is evaluated? Explain your Banswer by indicating what happens in every executed statement.

# %%
a = 0
def b():
    global a
    a = c(a)

def c(a):
    return a + 2

# %%
#Answer

b()
b()
b()
print(a)
# Out:
# 6

# %% [markdown]
# 1) The code begins by calling the function b().
# 2) Within b(), the global variable a is used, allowing it to be accessed and modified globally.
# 3) The function c(a) is invoked within b(), taking the current value of a and adding 2.
# 4) After each call to b(), a is updated globally, starting at 0 and increasing by 2 with each iteration.
# 5) The code continues to execute, progressively incrementing a to 2, 4, 6, and so on.

# %% [markdown]
# ## Question 2
#
# ### Function fileLength(), given to you, takes the name of a file as input and returns
#
# the length of the file:
#
#     >>> fileLength('midterm.py')
#     284
#     >>> fileLength('idterm.py')
#     Traceback (most recent call last):
#     File "<pyshell#34>", line 1, in <module>
#
# fileLength('idterm.py')
# File "/Users/me/midterm.py", line 3, in fileLength
# infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
#
#     As shown above, if the file cannot be found by the interpreter or if it cannot be read
# as a text file, an exception will be raised. Modify function fileLength() so that a
# friendly message is printed instead:
#
#     >>> fileLength('midterm.py')
#     358
#     >>> fileLength('idterm.py')
#     File idterm.py not found.

# %%
#Answer

def fileLength(file_name):
    
    try:
        with open(file_name, 'r') as file:
            contents = file.read()
            return len(contents)
   
    except FileNotFoundError:
        return "File " + file_name + " not found."
    
print(fileLength("Filelength.txt"))
print(fileLength("Filelength1.txt"))
# Out:
# 123
# File Filelength1.txt not found.

# %% [markdown]
# ## Question 3
#
# ### Write a class named Marsupial that can be used as shown below:
#
#     >>> m = Marsupial()
#     >>> m.put_in_pouch('doll')
#     >>> m.put_in_pouch('firetruck')
#     >>> m.put_in_pouch('kitten')
#     >>> m.pouch_contents()
#     ['doll', 'firetruck', 'kitten']
#
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# moves the kangaroo by dx units along the x-axis and by dy units along the yaxis, and
# c. overloads the __str__ operator so it behaves as shown below.
#
#     >>> k = Kangaroo(0,0)
#     >>> print(k)
#     I am a Kangaroo located at coordinates (0,0)
#     >>> k.put_in_pouch('doll')
#     >>> k.put_in_pouch('firetruck')
#     >>> k.put_in_pouch('kitten')
#     >>> k.pouch_contents()
#     ['doll', 'firetruck', 'kitten']
#     >>> k.jump(1,0)
#     >>> k.jump(1,0)
#     >>> k.jump(1,0)
#     >>> print(k)
#     I am a Kangaroo located at coordinates (3,0)

# %%
#Answer

class Marsupial:
    def __init__(self):
        self.pouch = []

    def put_in_pouch(self, item):
        self.pouch.append(item)

    def pouch_contents(self):
        return self.pouch


class Kangaroo(Marsupial):
    def __init__(self, x, y):
        # Initialize a Kangaroo object with coordinates (x, y)
        Marsupial.__init__(self) # Call the Marsupial's constructor to initialize the pouch
        self.x = x
        self.y = y

    def jump(self, x2, y2):
        #Jumping the Kangaroo according to x2,y2
        self.x += x2
        self.y += y2

    def __str__(self):
        return ("I am a Kangaroo located at coordinates (" + str(self.x) + ", " + str(self.y) +")")


m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
print(m.pouch_contents())

k = Kangaroo(0, 0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
print(k.pouch_contents())
k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)
# Out:
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (0, 0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3, 0)

# %% [markdown]
# ## Question 4
# ### Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
#
# #### x = {𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛 and 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
#
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.
#
#     >>> collatz(1)
#     1
#     >>> collatz(10)
#     10
#     5
#     16
#     8
#     4
#     2
#     1

# %%
# Answer:

def collatz(num):
    if(num == 1):
        print(1)
    elif num%2==0:
        print(num)
        collatz(num//2)
    else:
        print(num)
        (collatz(3*(num) + 1))


collatz(1)
collatz(10)
# Out:
# 1
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# ## Question 5
# ### Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.
#     >>> binary(0)
#     0
#     >>> binary(1)
#     1
#     >>> binary(3)
#     11
#     >>> binary(9)
#     1001

# %%
# Answer:

def binary(num):
    if num < 0:
        return "Number is not Positive"
    if num==0:
        return num
    print(num%2,end="")
    binary(num//2)

print(binary(0))

binary(1)
print("\n",end="")
binary(3)
print("\n",end="")
binary(9)
# Out:
# 0
# 1
# 11
# 1001

# %% [markdown]
# ## Question 6
#
# Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.
#
#     >>> infile = open('w3c.html')
#     >>> content = infile.read()
#     >>> infile.close()
#     >>> hp = HeadingParser()
#     >>> hp.feed(content)
#     W3C Mission
#     Principles

# %%
# Answer:
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self.heading_list = [False]*6

    def handle_starttag(self, tag, attrs):
        if tag in ['h1','h2','h3','h4','h5','h6']:
            self.heading_list[int(tag[-1])-1] = True

    def handle_endtag(self, tag):
        if tag in ['h1','h2','h3','h4','h5','h6']:
            self.heading_list[int(tag[-1])-1] = False

    def handle_data(self, data):
        for i, heading in enumerate(self.heading_list):
            if heading:
                print(" "*i+data)
infile=open('w3c.txt')
content=infile.read()
infile.close()
hp=HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
#  Principles

# %% [markdown]
# ## Question 7
#
#  Implement recursive function webdir() that takes as input: a URL (as a string) and non-negative integers depth and indent. Your function should visit every web page reachable from the starting URL web page in depth clicks or less, and print each web page's URL. As shown below, indentation, specified by indent, should be used to indicate the depth of a URL.
#
#     >>>webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0)
#         http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
#              http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
#                  http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
#              http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
#                  http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
# Answer:
from urllib.request import urlopen
from html.parser import HTMLParser

# Define a custom HTML parser to extract links from web pages
class LinkParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self.links = []

    def handle_starttag(self, tag, attrs):
        if tag == 'a':
            for attr, value in attrs:
                if attr == 'href':
                    self.links.append(value)

# Define the webdir function to visit web pages and extract links
def webdir(url, depth, indent):
    if depth < 0:
        return

    try:
        # Fetch the web page content using urlopen
        response = urlopen(url)
        content = response.read().decode()

        # Print the current URL with proper indentation
        print(' ' * indent + url)

        if depth > 0:
            # Create an instance of the LinkParser to extract links from the content
            link_parser = LinkParser()
            link_parser.feed(content)
            links = link_parser.links

            for link in links:
                if link.startswith('http'):
                    # Recursively call webdir on linked URLs with decreased depth and increased indentation
                    webdir(link, depth - 1, indent + 4)

    except Exception as e:
        # Print an error message if there's an issue with the URL or web page
        print(' ' * indent, " Error: ", str(e))


webdir('http://web.simmons.edu/~grovesd/comm244/notes/week3/html-test-page.html', 2, 0)
# Out:
# http://web.simmons.edu/~grovesd/comm244/notes/week3/html-test-page.html
#     http://web.simmons.edu/~grovesd/comm244
#         http://web.simmons.edu/~grovesd/comm244/
#         http://web.simmons.edu/~grovesd/comm244/week1
#         http://web.simmons.edu/~grovesd/comm244/week2
#         http://web.simmons.edu/~grovesd/comm244/week3
#         http://web.simmons.edu/~grovesd/comm244/week4
#         http://web.simmons.edu/~grovesd/comm244/week5
#         http://web.simmons.edu/~grovesd/comm244/week6
#         http://web.simmons.edu/~grovesd/comm244/week7
#         http://web.simmons.edu/~grovesd/comm244/week8
#         http://web.simmons.edu/~grovesd/comm244/week9
#         http://web.simmons.edu/~grovesd/comm244/week10
#         http://web.simmons.edu/~grovesd/comm244/week11
#         http://web.simmons.edu/~grovesd/comm244/week12
#         http://web.simmons.edu/~grovesd/comm244/week13
#         http://web.simmons.edu/~grovesd/comm244/recipebook
# ...

# %% [markdown]
# ## Question 8
# ### Write SQL queries on the below database table that return:
#
# a) All the temperature data.
#
# b) All the cities, but without repetition.
#
# c) All the records for India.
#
# d) All the Fall records.
#
# e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.
#
# f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
#
# g) The total annual rainfall for Cairo.
#
# h) The total rainfall for each season.

# %%
# Answer:

import sqlite3

table_data = [
    ("Mumbai", "India", "Winter", 24.8, 5.9),
    ("Mumbai", "India", "Spring", 28.4, 16.2),
    ("Mumbai", "India", "Summer", 27.9, 1549.4),
    ("Mumbai", "India", "Fall", 27.6, 346.0),
    ("London", "United Kingdom", "Winter", 4.2, 207.7),
    ("London", "United Kingdom", "Spring", 8.3, 169.6),
    ("London", "United Kingdom", "Summer", 15.7, 157.0),
    ("London", "United Kingdom", "Fall", 10.4, 218.5),
    ("Cairo", "Egypt", "Winter", 13.6, 16.5),
    ("Cairo", "Egypt", "Spring", 20.7, 6.5),
    ("Cairo", "Egypt", "Summer", 27.7, 0.1),
    ("Cairo", "Egypt", "Fall", 22.2, 4.5)
]

# Connect to the database (create it if it doesn't exist)
conn = sqlite3.connect('weather_data.db')

# Create a cursor to execute SQL queries
cur = conn.cursor()

#Drop the table if it exist
cur.execute("DROP TABLE IF EXISTS weather_data;")
# Create a table if it doesn't exist
cur.execute('''
    CREATE TABLE IF NOT EXISTS weather_data (
        City TEXT,
        Country TEXT,
        Season TEXT,
        Temperature FLOAT,
        Rainfall FLOAT
    )
''')

# Insert the data into the table row by row
for data in table_data:
    cur.execute('''
        INSERT INTO weather_data (City, Country, Season, Temperature, Rainfall)
        VALUES (?, ?, ?, ?, ?)
    ''', data)


conn.commit()
# Query 1
cur.execute('SELECT temperature FROM weather_data')
for record in cur:
    print("Query 1:",record)
# Query 2

cur.execute('SELECT DISTINCT city FROM weather_data')
for record in cur:
    print("Query 2:",record)

# Query 3
cur.execute('SELECT * FROM weather_data WHERE season = "Fall"')
for record in cur:
    print("Query 3:",record)

# Query 4
cur.execute('SELECT * FROM weather_data WHERE country = "India"')
for record in cur:
    print("Query 4:",record)

# Query 5
cur.execute('SELECT city, country FROM weather_data WHERE (season = "Fall") AND (temperature > 20) ORDER BY temperature DESC')
for record in cur:
    print("Query 5:",record)

# Query 6
cur.execute('SELECT city, country, season FROM weather_data WHERE (rainfall > 200) AND (rainfall < 400)')
for record in cur:
    print("Query 6:",record)

# Query 7
cur.execute('SELECT SUM(rainfall) FROM weather_data WHERE city = "Cairo"')
Annual_rainfall = cur.fetchall()
print("Query 6:",Annual_rainfall)

# Query 8
cur.execute('SELECT SUM(rainfall), season FROM weather_data GROUP BY season')
for record in cur:
    print("Query 7:",record)


conn.close()
# Out:
# Query 1: (24.8,)
# Query 1: (28.4,)
# Query 1: (27.9,)
# Query 1: (27.6,)
# Query 1: (4.2,)
# Query 1: (8.3,)
# Query 1: (15.7,)
# Query 1: (10.4,)
# Query 1: (13.6,)
# Query 1: (20.7,)
# Query 1: (27.7,)
# Query 1: (22.2,)
# Query 2: ('Mumbai',)
# Query 2: ('London',)
# Query 2: ('Cairo',)
# Query 3: ('Mumbai', 'India', 'Fall', 27.6, 346.0)
# Query 3: ('London', 'United Kingdom', 'Fall', 10.4, 218.5)
# Query 3: ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)
# Query 4: ('Mumbai', 'India', 'Winter', 24.8, 5.9)
# Query 4: ('Mumbai', 'India', 'Spring', 28.4, 16.2)
# Query 4: ('Mumbai', 'India', 'Summer', 27.9, 1549.4)
# Query 4: ('Mumbai', 'India', 'Fall', 27.6, 346.0)
# Query 5: ('Mumbai', 'India')
# Query 5: ('Cairo', 'Egypt')
# Query 6: ('Mumbai', 'India', 'Fall')
# Query 6: ('London', 'United Kingdom', 'Winter')
# Query 6: ('London', 'United Kingdom', 'Fall')
# Query 6: [(27.6,)]
# Query 7: (569.0, 'Fall')
# Query 7: (192.29999999999998, 'Spring')
# Query 7: (1706.5, 'Summer')
# ...

# %% [markdown]
# ## Question 9
#
# ### Suppose list words is defined as follows:
#
# words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
# Write list comprehension expressions that use list words and generate the following
# lists:
#
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
#
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list words).
#
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list words, where each list contains the word in uppercase and lowercase and the
# length of the word.)
#
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog'] (the list of words in list words containing 4 or more characters.

# %%
# Answer:

words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# a) Uppercase version of each word
print([word.upper() for word in words])

# b) Lowercase version of each word
print([word.lower() for word in words])

# c) List of lengths of words
print([len(word) for word in words])

# d) List containing uppercase, lowercase, and word length for each word
print([[word.upper(), word.lower(), len(word)] for word in words])

# e) List of words with 4 or more characters
print([word for word in words if len(word) >= 4])
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
